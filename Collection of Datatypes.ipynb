# %% [markdown]
# Collection of data types is a container used to store multiple data items.

# %% [markdown]
# **List**
#
#
# List is a oriented sequence.
# Mutable collection of data.
# Theorotically of infinite length.
# Iterable.
# Allow duplicate members.
# return with square brackets.

# %%
list1 = ['shahla','fathima','nasrin',23,56,67]
print(list1)
# Out:
# ['shahla', 'fathima', 'nasrin', 23, 56, 67]

# %% [markdown]
# Nested List

# %%
list2=[['shahla',20],['fathima',21],123,456]
print(list2)
# Out:
# [['shahla', 20], ['fathima', 21], 123, 456]

# %% [markdown]
# **INDEXING**
#
# Positive Indexing and Negative Indexing

# %%
list1=[['shalu',20],['path',21],'ramu','dolu','bolu']
print(list1[0])
# Out:
# ['shalu', 20]

# %%
list1[-3]
# Out:
# 'ramu'

# %%
list1[-5]
# Out:
# ['shalu', 20]

# %% [markdown]
# **SLICING**

# %%
print(list1[0:3])
# Out:
# [['shalu', 20], ['path', 21], 'ramu']

# %%
print(list1[1:-1])
print(list1[1:4])
print(list1[-4:-1])
# Out:
# [['path', 21], 'ramu', 'dolu']
# [['path', 21], 'ramu', 'dolu']
# [['path', 21], 'ramu', 'dolu']

# %% [markdown]
# **APPEND**

# %%
list1 = ['hello','world',123,456]
list1
# Out:
# ['hello', 'world', 123, 456]

# %%
list1.append('python')
list1
# Out:
# ['hello', 'world', 123, 456, 'python']

# %% [markdown]
# **EXTEND**

# %%
list2=['shalu','fathm']
list2
# Out:
# ['shalu', 'fathm']

# %%
list2.extend(['hello','world'])
list2
# Out:
# ['shalu', 'fathm', 'hello', 'world']

# %% [markdown]
# **POP**

# %%
list3 = ['shaaluu','shahla',123,456]
list3
# Out:
# ['shaaluu', 'shahla', 123, 456]

# %%
list3.pop()
# Out:
# 456

# %%
list3.pop(2)
# Out:
# 123

# %% [markdown]
# **INSERT**

# %%
list = [123,'hello','world']
list
# Out:
# [123, 'hello', 'world']

# %%
list.insert(1,'python')
list
# Out:
# [123, 'python', 'hello', 'world']

# %% [markdown]
# **REMOVE**

# %%
list1=['shalu','ramu']
list1
# Out:
# ['shalu', 'ramu']

# %%
list1.remove('ramu')
list1
# Out:
# ['shalu']

# %% [markdown]
# **DELETE**

# %%
list5 = ['hello','python',234,890,456]
list5
# Out:
# ['hello', 'python', 234, 890, 456]

# %%
del list5[3]
list5
# Out:
# ['hello', 'python', 234, 456]

# %% [markdown]
# **COUNT**

# %%
list = [123,456,789,12,34,12,00,78]
list
# Out:
# [123, 456, 789, 12, 34, 12, 0, 78]

# %%
list.count(12)
# Out:
# 2

# %% [markdown]
# **sum**

# %%
list8 = [5,7,8,9,4,3,,2,5,9]
list8
# Out:
#   File "<ipython-input-36-2cab0a1e454b>", line 1
#     list8 = [5,7,8,9,4,3,,2,5,9]
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# **length**

# %%
len(list)
# Out:
# 8

# %%
list1 = [25,5,12,6,7,33,65,14,54]

# %%
sum(list1)
# Out:
# 221

# %%
min(list1)
# Out:
# 5

# %%
max(list1)
# Out:
# 65

# %%
list = [34,67,89,33,98,9,4,8,9]
list.sort(reverse = True)

# %%
list2 = [35,65,24,75,35,75,32,66,22,44]
list2.sort(reverse = True)

# %%
list2
# Out:
# [75, 75, 66, 65, 44, 35, 35, 32, 24, 22]

# %%
list2.reverse()
